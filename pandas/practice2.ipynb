# %%
import pandas as pd

# %%
from sklearn.datasets import fetch_california_housing

# %%
df = fetch_california_housing(as_frame=True).frame
df
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude  MedHouseVal
# ...

# %%
df.head(10)
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# 5  4.0368      52.0  4.761658   1.103627       413.0  2.139896     37.85
# 6  3.6591      52.0  4.931907   0.951362      1094.0  2.128405     37.84
# 7  3.1200      52.0  4.797527   1.061824      1157.0  1.788253     37.84
# 8  2.0804      42.0  4.294118   1.117647      1206.0  2.026891     37.84
# 9  3.6912      52.0  4.970588   0.990196      1551.0  2.172269     37.84
#
#    Longitude  MedHouseVal
# 0    -122.23        4.526
# 1    -122.22        3.585
# 2    -122.24        3.521
# 3    -122.25        3.413
# 4    -122.25        3.422
# ...

# %%
df.sample(10) # 10 random rows
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 4366   6.4459      51.0  6.174510   1.017647      1082.0  2.121569     34.10
# 13815  2.6576       5.0  5.939206   1.129032      1944.0  2.411911     34.44
# 20556  1.9510      17.0  3.838451   1.081442      1876.0  2.504673     38.67
# 5025   3.7167      43.0  5.418103   1.000000       735.0  3.168103     33.99
# 6894   5.9941      23.0  6.495274   1.068053      1729.0  3.268431     34.05
# 20379  4.2857      16.0  5.273011   1.140406      1227.0  1.914197     34.15
# 20240  3.5000      46.0  4.748252   1.111888       382.0  2.671329     34.27
# 6243   3.7454      35.0  5.629808   1.024038      2176.0  5.230769     34.05
# 12811  3.9615      17.0  5.493506   1.008658       494.0  2.138528     38.65
# 3953   9.6465       5.0  7.902475   0.967977      2315.0  3.369723     34.21
#
#        Longitude  MedHouseVal
# 4366     -118.27      4.21600
# 13815    -117.22      0.98500
# ...

# %%
list(df.columns)
# Out:
# ['MedInc',
#  'HouseAge',
#  'AveRooms',
#  'AveBedrms',
#  'Population',
#  'AveOccup',
#  'Latitude',
#  'Longitude',
#  'MedHouseVal']

# %%
pd.options.display.max_columns = 5

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   MedInc       20640 non-null  float64
#  1   HouseAge     20640 non-null  float64
#  2   AveRooms     20640 non-null  float64
#  3   AveBedrms    20640 non-null  float64
#  4   Population   20640 non-null  float64
#  5   AveOccup     20640 non-null  float64
#  6   Latitude     20640 non-null  float64
#  7   Longitude    20640 non-null  float64
#  8   MedHouseVal  20640 non-null  float64
# dtypes: float64(9)
# memory usage: 1.4 MB

# %%
df.describe()
# Out:
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.870671     28.639486      5.429000      1.096675   1425.476744
# std        1.899822     12.585558      2.474173      0.473911   1132.462122
# min        0.499900      1.000000      0.846154      0.333333      3.000000
# 25%        2.563400     18.000000      4.440716      1.006079    787.000000
# 50%        3.534800     29.000000      5.229129      1.048780   1166.000000
# 75%        4.743250     37.000000      6.052381      1.099526   1725.000000
# max       15.000100     52.000000    141.909091     34.066667  35682.000000
#
#            AveOccup      Latitude     Longitude   MedHouseVal
# count  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.070655     35.631861   -119.569704      2.068558
# std       10.386050      2.135952      2.003532      1.153956
# ...

# %%
df.HouseAge # column of the data frame is series 
# or df['HouseAge']

# %%
df['HouseAge'].mean() #mode, sum
# Out:
# 28.639486434108527

# %%
import matplotlib.pyplot as plt
df.HouseAge.hist() # histograph of matplotlib
plt.title('House Age')
plt.show()

# %%
df = pd.DataFrame({
    "name": ["Alice", "Bob", "Charlie", "Diana", "Ethan"],
    "age": [24, 30, 35, 28, 40],
    "city": ["Tbilisi", "Batumi", "Kutaisi", "Rustavi", "Zugdidi"],
    "score": [88, 92, 79, 85, 95]
})

# %%
df.loc[1]
# Out:
# name        Bob
# age          30
# city     Batumi
# score        92
# Name: 1, dtype: object

# %%
df = df.set_index('name')
df
# Out:
#          age     city  score
# name
# Alice     24  Tbilisi     88
# Bob       30   Batumi     92
# Charlie   35  Kutaisi     79
# Diana     28  Rustavi     85
# Ethan     40  Zugdidi     95

# %%
df.loc['Alice']
# Out:
# age           24
# city     Tbilisi
# score         88
# Name: Alice, dtype: object

# %%
df.iloc[1]
# Out:
# age          30
# city     Batumi
# score        92
# Name: Bob, dtype: object

# %%
df.loc['Alice', 'age']
# Out:
# 24

# %%
df.iloc[1, 0]
# Out:
# 30

# %%
df.at['Alice', 'age']
# Out:
# 24

# %%
df.iat[1,0]
# Out:
# 30

# %%
df.at['Alice', 'age'] = 60

# %%
df.loc['Alice'] = [75, 'Chiatura', 88]

# %%
df.loc['John'] = [90, 'dubai',99]

# %%
df
# Out:
#          age      city  score
# name
# Alice     75  Chiatura     88
# Bob       30    Batumi     92
# Charlie   35   Kutaisi     79
# Diana     28   Rustavi     85
# Ethan     40   Zugdidi     95
# John      90     dubai     99

# %%
df.iloc[0:2, 1]
# Out:
# name
# Alice    Chiatura
# Bob        Batumi
# Name: city, dtype: object

# %%
df.iloc[:, 1]
# Out:
# name
# Alice      Chiatura
# Bob          Batumi
# Charlie     Kutaisi
# Diana       Rustavi
# Ethan       Zugdidi
# John          dubai
# Name: city, dtype: object

# %%
df.age = df.age * 2

# %%
def mf(x):
    if x%3 == 0: # endswith()
        return x**2
    return x

# %%
df.age.apply(mf)
# Out:
# name
# Alice      5625
# Bob         900
# Charlie      35
# Diana        28
# Ethan        40
# John       8100
# Name: age, dtype: int64

# %%
df.age.apply(lambda x: x ** 2 if x % 3 ==0 else x)
# Out:
# name
# Alice      5625
# Bob         900
# Charlie      35
# Diana        28
# Ethan        40
# John       8100
# Name: age, dtype: int64

# %%
df['summary'] = df.apply(lambda row: f'Age:{row["age"]}, city: {row["city"]}', axis=1)

# %%
df
# Out:
#          age      city  score                 summary
# name
# Alice     75  Chiatura     88  Age:75, city: Chiatura
# Bob       30    Batumi     92    Age:30, city: Batumi
# Charlie   35   Kutaisi     79   Age:35, city: Kutaisi
# Diana     28   Rustavi     85   Age:28, city: Rustavi
# Ethan     40   Zugdidi     95   Age:40, city: Zugdidi
# John      90     dubai     99     Age:90, city: dubai

# %%
df.drop('summary', axis=1)
# Out:
#          age      city  score
# name
# Alice     75  Chiatura     88
# Bob       30    Batumi     92
# Charlie   35   Kutaisi     79
# Diana     28   Rustavi     85
# Ethan     40   Zugdidi     95
# John      90     dubai     99

# %%
# data cleaning from nans
df.dropna() # drop all rows that have NaN values
# Out:
#          age      city  score                 summary
# name
# Alice     75  Chiatura     88  Age:75, city: Chiatura
# Bob       30    Batumi     92    Age:30, city: Batumi
# Charlie   35   Kutaisi     79   Age:35, city: Kutaisi
# Diana     28   Rustavi     85   Age:28, city: Rustavi
# Ethan     40   Zugdidi     95   Age:40, city: Zugdidi
# John      90     dubai     99     Age:90, city: dubai

# %%
df.fillna(-1) # fill nan values
df.age.fillna(df.age.mean())

# %%
# wanna drop not all nans, but those who are in a certain column
df.notna()
# Out:
#           age  city  score  summary
# name
# Alice    True  True   True     True
# Bob      True  True   True     True
# Charlie  True  True   True     True
# Diana    True  True   True     True
# Ethan    True  True   True     True
# John     True  True   True     True

# %%
# use this booleans to filter rows
df[df.age.notna()] # darcha mxolod validuri ageis mqonde rowebi
# Out:
#          age      city  score                 summary
# name
# Alice     75  Chiatura     88  Age:75, city: Chiatura
# Bob       30    Batumi     92    Age:30, city: Batumi
# Charlie   35   Kutaisi     79   Age:35, city: Kutaisi
# Diana     28   Rustavi     85   Age:28, city: Rustavi
# Ethan     40   Zugdidi     95   Age:40, city: Zugdidi
# John      90     dubai     99     Age:90, city: dubai

# %%
for i, row in df.iterrows(): # iteration rows
    print(row)
# Out:
# age                            75
# city                     Chiatura
# score                          88
# summary    Age:75, city: Chiatura
# Name: Alice, dtype: object
# age                          30
# city                     Batumi
# score                        92
# summary    Age:30, city: Batumi
# Name: Bob, dtype: object
# age                           35
# city                     Kutaisi
# score                         79
# summary    Age:35, city: Kutaisi
# Name: Charlie, dtype: object
# age                           28
# city                     Rustavi
# score                         85
# summary    Age:28, city: Rustavi
# Name: Diana, dtype: object
# age                           40
# city                     Zugdidi
# score                         95
# summary    Age:40, city: Zugdidi
# Name: Ethan, dtype: object
# age                         90
# city                     dubai
# score                       99
# summary    Age:90, city: dubai
# ...

# %%
for i, col in df.items(): # iteration cols
    print(col)
# Out:
# name
# Alice      75
# Bob        30
# Charlie    35
# Diana      28
# Ethan      40
# John       90
# Name: age, dtype: int64
# name
# Alice      Chiatura
# Bob          Batumi
# Charlie     Kutaisi
# Diana       Rustavi
# Ethan       Zugdidi
# John          dubai
# Name: city, dtype: object
# name
# Alice      88
# Bob        92
# Charlie    79
# Diana      85
# Ethan      95
# John       99
# Name: score, dtype: int64
# name
# Alice      Age:75, city: Chiatura
# Bob          Age:30, city: Batumi
# Charlie     Age:35, city: Kutaisi
# Diana       Age:28, city: Rustavi
# Ethan       Age:40, city: Zugdidi
# John          Age:90, city: dubai
# Name: summary, dtype: object

# %%
df.age > 50
# Out:
# name
# Alice       True
# Bob        False
# Charlie    False
# Diana      False
# Ethan      False
# John        True
# Name: age, dtype: bool

# %%
# ~ is not here

# %%
df[~df.city.str.endswith('i')]
# Out:
#        age      city  score                 summary
# name
# Alice   75  Chiatura     88  Age:75, city: Chiatura

# %%
import datetime as dt
df['birthday'] = df['age'].apply(lambda x: dt.datetime.now() - dt.timedelta(days=365*x))

# %%
df
# Out:
#          age      city  score                 summary  \
# name
# Alice     75  Chiatura     88  Age:75, city: Chiatura
# Bob       30    Batumi     92    Age:30, city: Batumi
# Charlie   35   Kutaisi     79   Age:35, city: Kutaisi
# Diana     28   Rustavi     85   Age:28, city: Rustavi
# Ethan     40   Zugdidi     95   Age:40, city: Zugdidi
# John      90     dubai     99     Age:90, city: dubai
#
#                           birthday
# name
# Alice   1950-10-17 17:14:46.146859
# Bob     1995-10-06 17:14:46.146859
# Charlie 1990-10-07 17:14:46.146859
# Diana   1997-10-05 17:14:46.146859
# Ethan   1985-10-08 17:14:46.146859
# John    1935-10-21 17:14:46.146859

# %%
ages = [30, 80]
df[df.age.isin(ages)]
# Out:
#       age    city  score               summary                   birthday
# name
# Bob    30  Batumi     92  Age:30, city: Batumi 1995-10-06 17:14:46.146859

# %%
df.query('age > 30') # no square syntax, numexpr
# Out:
#          age      city  score                 summary  \
# name
# Alice     75  Chiatura     88  Age:75, city: Chiatura
# Charlie   35   Kutaisi     79   Age:35, city: Kutaisi
# Ethan     40   Zugdidi     95   Age:40, city: Zugdidi
# John      90     dubai     99     Age:90, city: dubai
#
#                           birthday
# name
# Alice   1950-10-17 17:14:46.146859
# Charlie 1990-10-07 17:14:46.146859
# Ethan   1985-10-08 17:14:46.146859
# John    1935-10-21 17:14:46.146859

# %%
df.groupby('city').agg({
    'age': 'mean'
})
# Out:
#            age
# city
# Batumi    30.0
# Chiatura  75.0
# Kutaisi   35.0
# Rustavi   28.0
# Zugdidi   40.0
# dubai     90.0

# %%
df.sort_values('age', ascending=False)
# Out:
#          age      city  score                 summary  \
# name
# John      90     dubai     99     Age:90, city: dubai
# Alice     75  Chiatura     88  Age:75, city: Chiatura
# Ethan     40   Zugdidi     95   Age:40, city: Zugdidi
# Charlie   35   Kutaisi     79   Age:35, city: Kutaisi
# Bob       30    Batumi     92    Age:30, city: Batumi
# Diana     28   Rustavi     85   Age:28, city: Rustavi
#
#                           birthday
# name
# John    1935-10-21 17:14:46.146859
# Alice   1950-10-17 17:14:46.146859
# Ethan   1985-10-08 17:14:46.146859
# Charlie 1990-10-07 17:14:46.146859
# Bob     1995-10-06 17:14:46.146859
# Diana   1997-10-05 17:14:46.146859

# %%
df1 = pd.DataFrame({
    'Item': ['A', 'B', 'C'],
    'Price': [10, 20, 30]
})

df2 = pd.DataFrame({
    'Item': ['D', 'E', 'F'],
    'Price': [40, 50, 60]
})

# %%
# joining dataframes
df3 = pd.concat([df1, df2]).reset_index().drop('index', axis=1)
df3 = df3.sort_values('Item')

# %%
df4 = pd.DataFrame({
    'Country': ['X', 'Y', 'Z'],
    'Available': [True, True, False]
})

# %%
df5 = pd.concat([df1, df4], axis=1)
df5
# Out:
#   Item  Price Country  Available
# 0    A     10       X       True
# 1    B     20       Y       True
# 2    C     30       Z      False

# %%
df4 = pd.DataFrame({
    'Item': ['A', 'B', 'Z'],
    'Available': [True, True, False]
})

# %%
pd.merge(df1, df4)
# Out:
#   Item  Price  Available
# 0    A     10       True
# 1    B     20       True

# %%
pd.merge(df1, df4, on='Item', how='outer') # gaertianebaa
# Out:
#   Item  Price Available
# 0    A   10.0      True
# 1    B   20.0      True
# 2    C   30.0       NaN
# 3    Z    NaN     False

# %%
df4 = pd.DataFrame({
    'Available': [True, True, False]
}, index=['A', 'B', 'Z'],),
df5 = pd.DataFrame({
    'Country': ['X', 'Y', 'Z'],
}, index=['B', 'C', 'A'],),

# %%
df4.join(df5)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[86], line 1
# ----> 1 df4.join(df5)
#
# AttributeError: 'tuple' object has no attribute 'join'
